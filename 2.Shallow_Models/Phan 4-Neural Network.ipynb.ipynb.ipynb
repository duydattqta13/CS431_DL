# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %%
NAME = "Nguyễn Duy Đạt"

# %% [markdown]
# ---

# %% [markdown]
# # CÀI ĐẶT MÔ HÌNH NEURAL NETWORK VỚI KERAS

# %% [markdown]
# Một mô hình máy học cần có đủ ít nhất 7 phương thức sau:
# - `__init__`: hàm constructor trong hướng đối tượng, được sử dụng để khởi tạo các tham số mặc định hoặc tham số bắt đầu một mô hình. Trong những bài tập đầu tiên, để đơn giản constructor sẽ không sử dụng.
# - `build`: xây dựng kiến trúc của mô hình
# - `train`: bắt đầu quá trình huấn luyện mô hình
# - `save`: lưu lại mô hình sau khi đã huấn luyện
# - `load`: load lên mô hình từ file đã huấn luyện (pretrained)
# - `summary`: in tóm tắt kiến trúc mô hình
# - `predict`: dự đoán giá trị output từ dữ liệu đầu vào

# %%
# Mô hình cài đặt tổng quát bao gồm 7 phương thức cơ bản
# Lưu ý: mô hình này chỉ mang tính gợi ý, không bắt buộc
# Tuy nhiên, trong phần bài tập cần tuân theo các tên phương thức này
class MyModel:
    # constructor
    def __init__(self):
        return None
  
    # Implement architecture of the model
    def build(self):
        return None

    # Train the defined model with training and validation data 
    def train(self):
        return None

    # Save the trained model to file
    def save(self, model_path):
        return None

    # Load pretrained model from file
    def load(self):
        return None
    # Visualize your model
    def summary(self):
        return None

    # Apply your model with new input data
    def predict(self):
        return None

# %% [markdown]
# ## 1. Import các thư viện Keras
#
# Đầu tiên, ta sẽ import các thư viện, module, hàm của `Keras`:
# - `Input`: để nhận dữ liệu đầu vào cho mô hình
# - `Dense`: hay còn gọi là lớp Fully Connected (Lớp kết nối đầy đủ), một thành phần quan trọng của các mô hình dựa trên mạng Neural Network.
# - `Model`: đây là lớp đối tượng mô hình được sử dụng để đóng gói lớp đầu vào, đầu ra, sau đó huấn luyện với phương thức `fit` và dự đoán kết quả với `predict`.
# - `load_model`: hàm sử dụng để load mô hình lên từ file

# %%
from keras.layers import Input, Dense
from keras import Model
import tensorflow as tf
from keras.models import load_model
import numpy as np

# %% [markdown]
# ## 2. Cài đặt mô hình Neural Network
# Tiếp theo, ta sẽ dựa trên khung đối tượng `MyModel` đã trình bày ở mục trước để tiến hành cài đặt mô hình **Neural Network**. Phương thức chính mà bài tập này cần thực hiện là `def build()`. Các phương thức còn lại đã được cài đặt sẵn, các bạn cần đọc, hiểu ý nghĩa và cách thức sử dụng về sau.
#
# <p align="center">
#   <img src="NeuralNet.png" />
# </p>

# %%
# Neural Network
class NeuralNetwork:
    def __init__(self): # Self is similar to your 'this' pointer in C++
        return None

    def build(self, input_dim, output_dim, n_hidden, n_neurons):
        # `input_dim`: kích thước input feature
        # `output_dim`: số phân lớp cần phân loại
        # `n_hidden`: số lượng lớp ẩn
        # `n_neurons`: số lượng neuron mỗi lớp ẩn
        
        # Khởi tạo model
        self.model = None
        
        # Hãy cài đặt để định nghĩa KIẾN TRÚC MÔ HÌNH và lưu ở thuộc tính `self.model`
        # với các biến đối tượng sau:
        #  - tạo biến `input` với lớp đối tượng `Input` của Keras, 
        #    truyền vào kích thước đầu vào `input_dim`
        #  - tạo `n_hidden`lớp ẩn biết rằng, mỗi lớp ẩn có `n_neurons`, có sử dụng bias
        #    activation là hàm `sigmoid`. Đầu ra của lớp ẩn này là đầu vào lớp ẩn sau.
        #  - tạo biến `output` với lớp đối tượng `Dense` của Keras,
        #    truyền vào các tham số:  kích thước output (chú ý PHÂN LOẠI ĐA LỚP),
        #    có sử dụng bias, CÓ SỬ DỤNG hàm activation là `softmax`. Đầu vào của lớp
        #    output chính là lớp ẩn cuối cùng.
        # Sau bước này, self.model sẽ đóng gói 2 biến `input` và `output` để tạo thành mô hình
        # YOUR CODE HERE
        input = Input(input_dim)
        n_hidden_layer = Dense(n_neurons, use_bias=True, activation='sigmoid')(input)
        for i in range(n_hidden - 1):
            n_hidden_layer = Dense(n_neurons, use_bias=True, activation='sigmoid')(n_hidden_layer)
        output = Dense(output_dim, use_bias=True, activation='softmax')(n_hidden_layer)
        self.model = Model(input, output)
        # raise NotImplementedError()
        
        return self.model

    def train(self, x_train, y_train, epochs=500):
        # Khởi tạo mặc định với số `epochs=50`, `learning_rate=0.05`
        opt = tf.keras.optimizers.SGD(learning_rate=0.05) # Stochastic Gradient Descent
        self.model.compile(optimizer=opt, loss='categorical_crossentropy') # CCE loss
        return self.model.fit(x_train, y_train, epochs=epochs)

    def save(self, model_file):
        return self.model.save(model_file)
  
    def load(self, model_file):
        self.model = load_model(model_file)

    def summary(self):
        self.model.summary()

    def predict(self, x_test):
        return self.model.predict(x_test)
  
    def get_weights(self, layer_id):
        return self.model.layers[layer_id].get_weights()

# %% [markdown]
# Tiếp theo, ta sẽ khởi tạo đối tượng NeuralNetwork và kiểm tra thử xem phương `build` đã cài đặt chính xác chưa.

# %%
nn = NeuralNetwork()
# Trong ví dụ này, ta sẽ khởi tạo input là một vector 1000 chiều, 
# bài toán cần phân loại 20 lớp đối tượng. Số lượng lớp ẩn là 3 
# và số neuron mỗi lớp ẩn là  10.
nn.build(1000, 20, 3, 10)

# %%
# Kiểm tra sơ bộ kiến trúc mạng gồm 2 + 3 = 5 lớp: Input, 3 lớp ẩn và Output
assert len(nn.model.layers)==5
assert str(type(nn.model.layers[0]))== "<class 'keras.engine.input_layer.InputLayer'>"
assert str(type(nn.model.layers[1]))== "<class 'keras.layers.core.dense.Dense'>"
assert str(type(nn.model.layers[2]))== "<class 'keras.layers.core.dense.Dense'>"
assert str(type(nn.model.layers[3]))== "<class 'keras.layers.core.dense.Dense'>"
assert str(type(nn.model.layers[4]))== "<class 'keras.layers.core.dense.Dense'>"
assert nn.model.layers[0].input_shape[0][1] == 1000
assert nn.model.layers[-1].output_shape[1] == 20
assert nn.model.layers[1].use_bias == True

# %%
# Kiểm tra với bộ test ẩn

# %% [markdown]
# ## 3. Tạo dữ liệu mẫu (toy example)
# Bước tiếp theo, ta sẽ tiến hành tạo mẫu dữ liệu để huấn luyện và kiểm thử.
#
# Dữ liệu được tạo ra là các điểm rải ngẫu nhiên xung quanh 4 cụm điểm:
# - [10, -2]
# - [2, 8]
# - [12, 8]
# - [-2, 0]
#
# Lưu ý rằng, 4 cụm điểm này rời nhau đủ xa để khi thêm nhiễu ngẫu nhiên,
# các điểm thuộc 4 cụm này vẫn không giao thoa nhau.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Số phân lớp: 4
K = 4
# Tạo bộ dữ  liệu gồm 4 điểm
# S1, S2, S3, S4 là tâm của 4 lớp
S1= np.array([[10,-2]])
S2= np.array([[2,8]])
S3= np.array([[12,8]])
S4= np.array([[-2,0]])

# 50 samples mỗi lớp
n_sample = 50
# Phát sinh các điểm với nhiễu ngẫu nhiên xung quanh 4 tâm
pts1 = S1 + np.random.normal(0, 1.5, size=(n_sample,2))
pts2 = S2 + np.random.normal(0, 1.5, size=(n_sample,2))
pts3 = S3 + np.random.normal(0, 1.5, size=(n_sample,2))
pts4 = S4 + np.random.normal(0, 1.5, size=(n_sample,2))

# Nối tất cả các mẫu thành một khối dữ liệu X (input feature) và Y (nhãn)
X_train = np.concatenate((pts1, pts2, pts3, pts4))
# Concatenate data labels to a single input variable Y
Y_train = np.concatenate(([0]*n_sample, [1]*n_sample, [2]*n_sample, [3]*n_sample))

# Chuyển Y từ dạng nhãn sang one-hot vector
Y_train = Y_train.astype(int)
Y_oh = np.zeros((Y_train.size, Y_train.max()+1 ))
Y_oh[np.arange(Y_train.size), Y_train] = 1

# Trực quan hóa dữ liệu bằng các hình tròn màu đỏ, xanh lá, xanh dương và vàng
plt.plot(pts1[:,0], pts1[:,1], 'ro')
plt.plot(pts2[:,0], pts2[:,1], 'go')
plt.plot(pts3[:,0], pts3[:,1], 'bo')
plt.plot(pts4[:,0], pts4[:,1], 'yo')
plt.show()

# %% [markdown]
# ## 4. Huấn luyện mô hình với dữ liệu mẫu
#
# Tiếp theo, ta sẽ khởi tạo lại mô hình để phù hợp với dữ liệu mẫu đã phát sinh ở bước trước. Việc xây dựng kiến trúc của mô hình phải phù hợp với số chiều của dữ liệu mẫu.

# %%
nn = NeuralNetwork()

# Hãy gọi phương thức `build` cho đối tượng `sr` và truyền tham số đầu vào
# tương ứng với dữ liệu train đã phát sinh ở code block trên
# Theo bạn, `input_dim`, `output_dim` bằng bao nhiêu?
# Đối với các lớp ẩn, ta khởi tạo 01 lớp ẩn và 03 neuron cho mỗi lớp ẩn

# YOUR CODE HERE
nn.build(2, 4, 1, 3)
# raise NotImplementedError()

# Để hiển thị kiến trúc của mô hình ta gọi phương thức `summary`
print("Kiến trúc của mô hình Neural Network: ")
nn.summary()
# Out:
# Kiến trúc của mô hình Neural Network:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 2)]               0
#
#  dense_4 (Dense)             (None, 3)                 9
#
#  dense_5 (Dense)             (None, 4)                 16
#
# =================================================================
# Total params: 25
# Trainable params: 25
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Kiểm tra kết quả khi đối tượng `nn` gọi phương thức `build`

# %%
# Để huấn luyện mô hình ta gọi phương thức `train` với dữ liệu mẫu đã tạo được
# Nếu bước `build` mô hình gọi đúng thì bước `train` sau sẽ thực hiện thành công
# LƯU Ý: Ở đây ta sử dụng output là Y_oh dạng one-hot thay vì dạng nhãn (label)
hist = nn.train(X_train, Y_oh)
# Out:
# Epoch 1/500
# 7/7 [==============================] - 1s 3ms/step - loss: 1.3478
# Epoch 2/500
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2982
# Epoch 3/500
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2641
# Epoch 4/500
# 7/7 [==============================] - 0s 3ms/step - loss: 1.2366
# Epoch 5/500
# 7/7 [==============================] - 0s 3ms/step - loss: 1.2099
# Epoch 6/500
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1861
# Epoch 7/500
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1651
# Epoch 8/500
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1457
# Epoch 9/500
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1278
# Epoch 10/500
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1100
# Epoch 11/500
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0926
# Epoch 12/500
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0751
# Epoch 13/500
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0583
# Epoch 14/500
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0424
# Epoch 15/500
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0265
# Epoch 16/500
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0124
# Epoch 17/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9967
# Epoch 18/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9825
# Epoch 19/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9682
# Epoch 20/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9540
# Epoch 21/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9398
# Epoch 22/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9259
# Epoch 23/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9131
# Epoch 24/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9005
# Epoch 25/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8884
# Epoch 26/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8765
# Epoch 27/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8666
# Epoch 28/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8544
# Epoch 29/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8443
# Epoch 30/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8340
# Epoch 31/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8240
# Epoch 32/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8149
# Epoch 33/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8056
# Epoch 34/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7969
# Epoch 35/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7876
# Epoch 36/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7797
# Epoch 37/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7720
# Epoch 38/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7637
# Epoch 39/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7567
# Epoch 40/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7491
# Epoch 41/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7419
# Epoch 42/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7348
# Epoch 43/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7282
# Epoch 44/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7217
# Epoch 45/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7158
# Epoch 46/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7096
# Epoch 47/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7030
# Epoch 48/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6977
# Epoch 49/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6921
# Epoch 50/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6863
# Epoch 51/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6811
# Epoch 52/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6767
# Epoch 53/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6711
# Epoch 54/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6657
# Epoch 55/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6616
# Epoch 56/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6568
# Epoch 57/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6532
# Epoch 58/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6482
# Epoch 59/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6435
# Epoch 60/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6397
# Epoch 61/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6357
# Epoch 62/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6318
# Epoch 63/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6277
# Epoch 64/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6242
# Epoch 65/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6210
# Epoch 66/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6170
# Epoch 67/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0
500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1574
# Epoch 416/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1565
# Epoch 417/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1556
# Epoch 418/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1544
# Epoch 419/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1534
# Epoch 420/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1523
# Epoch 421/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1514
# Epoch 422/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1507
# Epoch 423/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1495
# Epoch 424/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1485
# Epoch 425/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1478
# Epoch 426/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1467
# Epoch 427/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1458
# Epoch 428/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1451
# Epoch 429/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1440
# Epoch 430/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1431
# Epoch 431/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1424
# Epoch 432/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1414
# Epoch 433/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1406
# Epoch 434/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1399
# Epoch 435/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1391
# Epoch 436/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1382
# Epoch 437/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1373
# Epoch 438/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1367
# Epoch 439/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1358
# Epoch 440/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1351
# Epoch 441/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1343
# Epoch 442/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1335
# Epoch 443/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1329
# Epoch 444/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1322
# Epoch 445/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1314
# Epoch 446/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1308
# Epoch 447/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1300
# Epoch 448/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1293
# Epoch 449/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1287
# Epoch 450/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1279
# Epoch 451/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1274
# Epoch 452/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1267
# Epoch 453/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1261
# Epoch 454/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1252
# Epoch 455/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1248
# Epoch 456/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1240
# Epoch 457/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1234
# Epoch 458/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1227
# Epoch 459/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1223
# Epoch 460/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1217
# Epoch 461/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1210
# Epoch 462/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1204
# Epoch 463/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1197
# Epoch 464/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1192
# Epoch 465/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1185
# Epoch 466/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1179
# Epoch 467/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1175
# Epoch 468/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1168
# Epoch 469/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1162
# Epoch 470/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1156
# Epoch 471/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1151
# Epoch 472/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1147
# Epoch 473/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1140
# Epoch 474/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1137
# Epoch 475/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1131
# Epoch 476/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1126
# Epoch 477/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1122
# Epoch 478/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1116
# Epoch 479/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1109
# Epoch 480/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1105
# Epoch 481/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1100
# Epoch 482/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1096
# Epoch 483/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1090
# Epoch 484/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1085
# Epoch 485/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1081
# Epoch 486/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1075
# Epoch 487/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1071
# Epoch 488/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1067
# Epoch 489/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1063
# Epoch 490/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1057
# Epoch 491/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1053
# Epoch 492/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1049
# Epoch 493/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1045
# Epoch 494/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1041
# Epoch 495/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1036
# Epoch 496/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1031
# Epoch 497/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1028
# Epoch 498/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1027
# Epoch 499/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1020
# Epoch 500/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1015

# %%
# Hiển thị loss theo số epoch
plt.plot(hist.history['loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# %%
# Sau khi đã huấn luyện, ta lưu mô hình về để sau này tái sử dụng
# Lưu ý: hai phương thức lưu mô hình `save` và tải mô hình lên 'load'
# được sử dụng khi muốn tái sử dụng nhiều lần mà KHÔNG CẦN PHẢI HUẤN LUYỆN LẠI
nn.save('neural_network_model.h5')

# %% [markdown]
# ## 5. Trực quan hóa mô hình và dự đoán với dữ liệu test

# %%
# Khởi tạo đối tượng mới và gọi phương thức load mô hình từ file
pretrain_nn = NeuralNetwork()
pretrain_nn.load('neural_network_model.h5')

# %%
# In ra bộ tham số tối ưu lớp cuối cùng
theta = pretrain_nn.get_weights(-1)
print('Tham số tối ưu: ')
print(theta)
# Out:
# Tham số tối ưu:
# [array([[-1.496693  ,  1.2531921 , -3.8963897 ,  3.7320886 ],
#        [-4.368241  ,  2.8139417 ,  3.642486  , -0.6990778 ],
#        [ 2.1445265 ,  0.2954082 ,  0.49635905, -3.6720996 ]],
#       dtype=float32), array([ 1.4870218 , -1.6391709 , -0.32397228,  0.4761208 ], dtype=float32)]

# %%
# Trực quan hóa dữ liệu và mô hình sau khi huấn luyện
# Ý tưởng: lấy mẫu dày đặc các điểm trong phạm vi dữ liệu train
# Sau đó dùng mô hình để dự đoán và hiển thị kết quả

# `colors` là các marker được sử dụng để trực quan hóa kết quả test
colors = ['r+', 'g+', 'b+', 'y+']
# `gt_colors` là các marker được sử dụng để trực quan hóa dữ liệu train
gt_colors = ['ro', 'go', 'bo', 'yo']

# Lấy mẫu dày đặc các điểm
x = np.arange(-8, 17, 1)
y = np.arange(-8, 17, 1)
xx, yy = np.meshgrid(x,y)

xx = xx.reshape(-1)
yy = yy.reshape(-1)

# Tạo các dữ liệu test dày đặc
X_test = np.concatenate([[xx],[yy]], axis=0).T
Y_pred = pretrain_nn.predict(X_test)

for i in range(len(xx)):
    plt.plot(xx[i],yy[i], colors[np.argmax(Y_pred[i])])
plt.plot(pts1[:,0], pts1[:,1], gt_colors[0])
plt.plot(pts2[:,0], pts2[:,1], gt_colors[1])
plt.plot(pts3[:,0], pts3[:,1], gt_colors[2])
plt.plot(pts4[:,0], pts4[:,1], gt_colors[3])
plt.show()
# Out:
# 20/20 [==============================] - 0s 2ms/step

# %% [markdown]
# Ta có thể thấy rằng, không gian mặt phẳng đã được phân loại sử dụng mô hình Neural Network đã huấn luyện trước đó. Dựa trên hình trên ta thấy kết quả khá chính xác, chỉ trừ một số điểm ở biên giữa các lớp.

# %% [markdown]
# ## 6. Thử nghiệm với tập dữ liệu  MNIST
#
# MNIST là tập dữ liệu chữ số viết tay kinh điển trong lĩnh vực máy học. Để tải và sử dụng dữ liệu này cực kỳ đơn giản chỉ với 2 dòng code:

# %%
# Prepare MNIST dataset
from keras.datasets import mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %% [markdown]
# Để hiểu rõ hơn về dữ liệu này, ta sẽ trực quan hóa dữ liệu bằng cách hiển thị ảnh và xem kích thước ảnh.

# %%
plt.imshow(x_train[1234])
print('Nhãn của mẫu dữ liệu thứ 1234: ', y_train[1234])
print('Kích thước của ảnh train: ', x_train[1234].shape)
print('Số điểm ảnh nếu biến đổi thành vector: ', 
      x_train[1234].shape[0]*x_train[1234].shape[1])
# Out:
# Nhãn của mẫu dữ liệu thứ 1234:  3
# Kích thước của ảnh train:  (28, 28)
# Số điểm ảnh nếu biến đổi thành vector:  784

# %% [markdown]
# Tiền xử lý dữ liệu trước khi huấn luyện mô hình:
# - Chuyển output sang dạng one-hot vector
# - Chuẩn hóa dữ liệu input về khoảng giá trị `[0-1]`

# %%
# Hàm chuyển đổi output từ dạng nhãn (label) sang vector one-hot
def onehot(y):
    oh = np.zeros((y.shape[0], y.max()+1))
    oh[np.arange(y.shape[0]), y] = 1
    return oh

y_train_oh = onehot(y_train)
y_test_oh = onehot(y_test)

# Chuẩn hóa dữ liệu input trên dữ liệu train và test
n_train_sample, h, w = x_train.shape
n_test_sample, _,_ = x_test.shape # Kích thước ngang x cao giống nhau trên tất cả mẫu

x_train = (x_train.astype('float32')) / 255.0
x_test = (x_test.astype('float32')) / 255.0
x_train_vec = x_train.reshape((n_train_sample, w*h))
x_test_vec = x_test.reshape((n_test_sample, w*h))

# %% [markdown]
# Khởi tạo mô hình từ đầu sao cho phù hợp với dữ liệu MNIST.
# Trong đó, thông tin cấu hình về lớp ẩn:
# - 2 lớp ẩn
# - 100 neuron mỗi lớp ẩn
# - huấn luyện với 30 epochs

# %%
nn4mnist = NeuralNetwork()

# Hoàn tất đoạn code sau đây với việc sử dụng biến `nn4mnist` để gọi
# phương thức `build`# và `train`. Lưu ý: sử dụng các tham số phù hợp
# theo yêu cầu đã nêu.
# YOUR CODE HERE
nn4mnist.build(784, 10, 2, 100)
hist = nn4mnist.train(x_train_vec, y_train_oh, epochs=30)
# raise NotImplementedError()
# Out:
# Epoch 1/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.2998
# Epoch 2/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4567
# Epoch 3/30
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3430
# Epoch 4/30
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3004
# Epoch 5/30
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2726
# Epoch 6/30
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2507
# Epoch 7/30
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2317
# Epoch 8/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2150
# Epoch 9/30
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2001
# Epoch 10/30
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1870
# Epoch 11/30
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1755
# Epoch 12/30
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1648
# Epoch 13/30
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1551
# Epoch 14/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1463
# Epoch 15/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1386
# Epoch 16/30
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1311
# Epoch 17/30
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1245
# Epoch 18/30
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1187
# Epoch 19/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1133
# Epoch 20/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1080
# Epoch 21/30
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1032
# Epoch 22/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0990
# Epoch 23/30
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0949
# Epoch 24/30
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0912
# Epoch 25/30
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0875
# Epoch 26/30
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0842
# Epoch 27/30
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0812
# Epoch 28/30
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0781
# Epoch 29/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0754
# Epoch 30/30
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0728

# %%
# Trực quan hóa giá trị loss trong quá trình huấn luyện
plt.plot(hist.history['loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# %%
# Kiểm tra sơ bộ biến `hist`: nếu quá trình khởi tạo và huấn luyện thành công
# thì các bài test sau sẽ vượt qua được.
assert hist is not None
assert 'loss' in hist.history
assert len(hist.history['loss']) == 30

# %%
# Kiểm tra với bộ test ẩn

# %% [markdown]
# Sau quá trình huấn luyện, chúng ta sử dụng mô hình để dự đoán trên mẫu dữ liệu test:

# %%
pred = nn4mnist.predict(x_test_vec)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# Cuối cùng, trực quan hóa một mẫu dữ liệu test bất kỳ (ví dụ mẫu thứ 50):

# %%
# Show the 50-th test sample
test_id = 50
plt.imshow(x_test[test_id])
print('Label of the data: ', y_test[test_id])
print('Predicted label of the data: ', np.argmax(pred[test_id]))
# Out:
# Label of the data:  6
# Predicted label of the data:  6
